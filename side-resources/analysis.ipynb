# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('precipitation.csv', sep=';').drop(columns=['Insolacao (h)', 'Vel. Vento (m/s)','Temp. Min. [Diaria] (h)', 'Nebulosidade (Decimos)', 'Dir. Vento (m/s)', 'Temp. Max. [Diaria] (h)'])
df['Chuva [Diaria] (mm)'] = df['Chuva [Diaria] (mm)'].fillna(0)
df['Data'] = pd.to_datetime(df['Data'])
df = df.fillna(0)
df
# Out:
# C:\Users\victo\AppData\Local\Temp\ipykernel_22676\711297745.py:3: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['Data'] = pd.to_datetime(df['Data'])
#           Data  Hora (UTC) Temp. [Hora] (C) Umi. (%) Pressao (hPa)  \
# 0   2024-04-29           0             19,2     81,0        1007,6
# 1   2024-04-29        1200             19,9     92,0        1005,5
# 2   2024-04-29        1800             20,9     98,0        1004,8
# 3   2024-04-30           0             20,5     96,0        1003,4
# 4   2024-04-30        1200             20,7     96,0        1006,7
# ..         ...         ...              ...      ...           ...
# 478 2024-10-05        1200             20,5     65,0        1014,6
# 479 2024-10-05        1800             25,9     55,0        1011,8
# 480 2024-10-06           0             18,4     80,0        1012,6
# ...

# %%
counter = 0
for eachNum in df['Pressao (hPa)']:
    try:
         df['Pressao (hPa)'][counter] = float(df['Pressao (hPa)'][counter])
         counter += 1
    except (AttributeError) as e:
        print(type(df['Pressao (hPa)'][counter]))
        
df.info
# Out:
# C:\Users\victo\AppData\Local\Temp\ipykernel_22676\4036534106.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Pressao (hPa)'][counter] = float(df['Pressao (hPa)'][counter])
# ...

# %%
teste = df.groupby(['Data'])['Chuva [Diaria] (mm)'].mean()

teste
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# ...
