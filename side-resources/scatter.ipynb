# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# norte1 = pd.read_table('norte1.txt', names=['x', 'y', 'z'], sep='     ')
# norte2 = pd.read_table('norte2.txt', names=['x', 'y', 'z'], sep='     ')
# norte3 = pd.read_table('norte3.txt', names=['x', 'y', 'z'], sep='     ')
# norte4 = pd.read_table('norte4.txt', names=['x', 'y', 'z'], sep='     ')
# norte5 = pd.read_table('norte5.txt', names=['x', 'y', 'z'], sep='     ')

# norte = pd.concat([norte1, norte2, norte3, norte4, norte5], axis=0)

# %%
# norte = pd.concat([norte1, norte2, norte3, norte4, norte5], axis=0)

# %%
medio1 = pd.read_table('medio1.txt', names=['latitude', 'longitude', 'topografia'], sep='     ')
medio2 = pd.read_table('medio2.txt', names=['latitude', 'longitude', 'topografia'], sep='     ')
medio3 = pd.read_table('medio3.txt', names=['latitude', 'longitude', 'topografia'], sep='     ')
medio4 = pd.read_table('medio4.txt', names=['latitude', 'longitude', 'topografia'], sep='     ')
medio5 = pd.read_table('medio5.txt', names=['latitude', 'longitude', 'topografia'], sep='     ')
# Out:
# C:\Users\victo\AppData\Local\Temp\ipykernel_14784\1177216698.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   medio1 = pd.read_table('medio1.txt', names=['latitude', 'longitude', 'topografia'], sep='     ')
# C:\Users\victo\AppData\Local\Temp\ipykernel_14784\1177216698.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   medio2 = pd.read_table('medio2.txt', names=['latitude', 'longitude', 'topografia'], sep='     ')
# ...

# %%
medio = pd.concat([medio4], axis=0)

# %%
submedio1 = pd.read_table('submedio1.txt', names=['latitude', 'longitude', 'topografia'], sep='     ')
submedio2 = pd.read_table('submedio2.txt', names=['latitude', 'longitude', 'topografia'], sep='     ')
submedio3 = pd.read_table('submedio3.txt', names=['latitude', 'longitude', 'topografia'], sep='     ')
submedio4 = pd.read_table('submedio4.txt', names=['latitude', 'longitude', 'topografia'], sep='     ')
submedio5 = pd.read_table('submedio5.txt', names=['latitude', 'longitude', 'topografia'], sep='     ')
# Out:
# C:\Users\victo\AppData\Local\Temp\ipykernel_14784\306343392.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   submedio1 = pd.read_table('submedio1.txt', names=['latitude', 'longitude', 'topografia'], sep='     ')
# C:\Users\victo\AppData\Local\Temp\ipykernel_14784\306343392.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   submedio2 = pd.read_table('submedio2.txt', names=['latitude', 'longitude', 'topografia'], sep='     ')
# ...

# %%
submedio = pd.concat([submedio4], axis=0)

# %%
sul1 = pd.read_table('sul1.txt', names=['latitude', 'longitude', 'topografia'], sep='     ')
sul2 = pd.read_table('sul2.txt', names=['latitude', 'longitude', 'topografia'], sep='     ')
sul3 = pd.read_table('sul3.txt', names=['latitude', 'longitude', 'topografia'], sep='     ')
sul4 = pd.read_table('sul4.txt', names=['latitude', 'longitude', 'topografia'], sep='     ')
sul5 = pd.read_table('sul5.txt', names=['latitude', 'longitude', 'topografia'], sep='     ')
# Out:
# C:\Users\victo\AppData\Local\Temp\ipykernel_14784\57362563.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   sul1 = pd.read_table('sul1.txt', names=['latitude', 'longitude', 'topografia'], sep='     ')
# C:\Users\victo\AppData\Local\Temp\ipykernel_14784\57362563.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   sul2 = pd.read_table('sul2.txt', names=['latitude', 'longitude', 'topografia'], sep='     ')
# ...

# %%
sul = pd.concat([ sul3, sul4, sul5])

# %%
terc = pd.concat([medio, submedio], axis=0)

# %%
newTIF = terc.plot.scatter(x='latitude', y='longitude', c='topografia', colormap='terrain', vmax=350)

# %%
newTIF.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 newTIF.savefig("poaRegiao")
#
# AttributeError: 'Axes' object has no attribute 'savefig'

# %%
terc.to_csv('possible_tif.csv')

# %%
submedio.to_csv('regiao_poa.csv')

# %%
# sul1.plot.scatter(x='x', y='y', c='z', colormap='OrRd')

# %%
# quad.plot.scatter(x='x', y='y', c='z', colormap='twilight_shifted')

# %%
# dual = pd.concat([medio4, medio5, submedio4, submedio5])

# %%
# dual.plot.scatter(x='x', y='y', c='z', colormap='twilight_shifted')

# %%
# submedio4.plot.scatter(x='x', y='y', c='z', colormap='twilight_shifted')

# %%
# terc.plot.scatter(x='x', y='y', c='z', colormap='twilight_shifted')

# %%
# quad = pd.concat([norte, medio, submedio, sul], axis=0)
# quad.to_csv('fullRegion.csv')

# %%
# quad.plot.scatter(x='x', y='y', c='z', colormap='inferno')
